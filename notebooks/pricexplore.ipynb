# %%
# %cd ../
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /raid/hkamarthi3/IUC_Project
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
DATA_FILE = "./IUC_Data/0102_ZHVI_230306.csv"
df = pd.read_csv(DATA_FILE)
print(df.columns)
df.head()
# Out:
# Index(['ZIP', 'SizeRank', 'RegionName', 'RegionType', 'StateName', 'State',
#        'City', 'Metro', 'CountyName', 'X2000.01.31',
#        ...
#        'X2022.04.30', 'X2022.05.31', 'X2022.06.30', 'X2022.07.31',
#        'X2022.08.31', 'X2022.09.30', 'X2022.10.31', 'X2022.11.30',
#        'X2022.12.31', 'X2023.01.31'],
#       dtype='object', length=286)
#      ZIP  SizeRank  RegionName RegionType StateName State      City  \
# 0  91940         0       77449        zip        TX    TX       NaN
# 1  91982         1       77494        zip        TX    TX       NaN
# 2  93144         2       79936        zip        TX    TX   El Paso
# 3  62080         3       11368        zip        NY    NY  New York
# 4  62093         4       11385        zip        NY    NY  New York
#
#                                    Metro        CountyName    X2000.01.31  \
# 0   Houston-The Woodlands-Sugar Land, TX     Harris County  111025.364504
# ...

# %%
STORM_FILE = "./IUC_Data/0101_StormData_230306.csv"
df_storm = pd.read_csv(STORM_FILE)
print(df_storm.columns)
df_storm.head()
# Out:
# Index(['Unnamed: 0', 'ZIP', '062008', '072008', '082008', '092008', '032009',
#        '042009', '112009', '012010', '032010', '072010', '102010', '092011',
#        '132011', '022012', '042012', '092012', '182012', '012013', '012014',
#        '012015', '022015', '032016', '092016', '112016', '142016', '032017',
#        '062017', '092017', '112017', '122017', '152017', '162017', '012018',
#        '062018', '072018', '142018', '022019', '052019', '112019', '142019',
#        '162019', '172019', '012020', '022020', '032020', '062020', '082020',
#        '092020', '132020', '142020', '192020', '202020', '222020', '262020',
#        '282020', '292020'],
#       dtype='object')
#    Unnamed: 0    ZIP  062008  072008  082008  092008  032009  042009  112009  \
# 0           1  35586     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1           2  19963     NaN     NaN    34.0     NaN     NaN     NaN     NaN
# ...

# %%
STORM_TIME_FILE = "./IUC_Data/0101_StormTime_230306.csv"
df_storm_time = pd.read_csv(STORM_TIME_FILE)
print(df_storm_time.columns)
df_storm_time
# Out:
# Index(['Unnamed: 0', 'Event', 'Start', 'End'], dtype='object')
#     Unnamed: 0   Event       Start         End
# 0            1   62008  2008081518  2008082318
# 1            2   72008  2008082512  2008090206
# 2            3   82008  2008082812  2008090700
# 3            4   92008  2008090112  2008091406
# 4            5   32009  2009081518  2009082406
# 5            6   42009  2009081612  2009081706
# 6            7  112009  2009110412  2009111006
# 7            8   12010  2010062606  2010070118
# 8            9   32010  2010072300  2010072315
# 9           10   72010  2010082518  2010090512
# 10          11  102010  2010090606  2010090718
# 11          12   92011  2011082100  2011082818
# 12          13  132011  2011090212  2011090500
# 13          14   22012  2012052518  2012053118
# 14          15   42012  2012062312  2012062618
# 15          16   92012  2012082118  2012083018
# 16          17  182012  2012102218  2012102918
# 17          18   12013  2013060518  2013060712
# ...

# %%
CENSUS_FILE = "./IUC_Data/0103_Census_2012-2016_230316.csv"
df_census = pd.read_csv(CENSUS_FILE)
print(df_census.columns)
df_census.head()
# Out:
# Index(['zip_code_tabulation_area', 'PopTot', 'PopPerChild', 'PopPerOld',
#        'PopMedAge', 'PopPerMale', 'PopPerFemale', 'PopPerWhite', 'PopPerBlack',
#        'PopPerAmInd', 'PopPerAsian', 'PopPerHawai', 'PopPerNever',
#        'PopPerMarSep', 'PopPerDiv', 'PopPerSep', 'PopPerWid', 'HousePerOwner',
#        'HousePerRent', 'HousePerFam', 'HousePerNonFam', 'HouseAveSize',
#        'HouseAveVeh', 'HouseAveWork', 'HouseAveRoom', 'HouseYr', 'HouseYrOwn',
#        'HouseYrRent', 'HouseConsYr', 'IncMed', 'IncPov', 'IncGini', 'IncMortg',
#        'IncRent', 'IncVal', 'MobRelocNo', 'MobRelocCty', 'MobRelocSt',
#        'MobRelocOut', 'MobPerModeCar', 'MobPerModePub', 'MobPerModeBkWk',
#        'MobAveTt', 'MobPerDesRes', 'MobPerDesOut', 'EduPerEnrl',
#        'EduPerTypePub', 'EduPerTypePrv', 'EduPerAttBac', 'EduPerAttHi',
#        'EmpLfpr', 'EmpUnemp', 'EmpOccMgmt', 'EmpOccSrv', 'EmpOccSale',
#        'EmpOccNatCons', 'EmpOccTrans'],
#       dtype='object')
# ...

# %% [markdown]
# # Models
# - RNN/Transformer + linear for regression (steps forward)
#   - One for each state
#   - One for each hurricane event
#   - Do LIME, SHAP, etc. to understand what's going on
# - Simple Regression/ RF/ XGBoost on past 6 months values plus features
#   - One for each state
#   - One for each hurricane event
#   - Do LIME, SHAP, etc. to understand what's going on
# - Same for forecasting and classification
